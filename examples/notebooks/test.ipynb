# %%
import time
print("Step 1 starting...")
time.sleep(5)
print("Step 1 done")
# Out:
# Step 1 starting...
# Step 1 done

# %%
print("Step 2 running...")

# %%
print("About to fail...")
#raise Exception("This is a test error!")

# %%
print("Step 1 starting...")
time.sleep(2)
print("Step 1 done")

# %%
print("Step 1 starting...")
time.sleep(2)
print("Step 1 done")

# %%
print("Step 1 starting...")
time.sleep(2)
print("Step 1 done")

# %%
print("Step 1 starting...")
time.sleep(2)
print("Step 1 done")

# %%
print("Step 1 starting...")
time.sleep(2)
print("Step 1 done")

# %%
print("I should not run because Cell 3 failed")
